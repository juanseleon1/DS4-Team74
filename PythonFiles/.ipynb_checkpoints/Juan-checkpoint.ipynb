# %% [markdown]
# # Notebook Juan

# %%
import numpy as np
import pandas as pd
import os
from os.path import dirname, abspath

# %% [markdown]
# ## Enviroment Settings

# %%
repo_dir = dirname(abspath(os.getcwd()))+"/Data/"

# %% [markdown]
# ## Work Orders Dataset

# %%
wold = pd.read_csv(repo_dir + 'HistoricoAdjuntosActivosOT.csv', delimiter=';',dtype='object')
wold.head()
# Out:
#   ASSETNUM SLXNUMACTEXT                                      SLXDESCACTEXT  \
# 0  2977237         2879  CIRCUITOS ALUMBRADO C/M TS-ALUMBRADO TOMAS 220...
# 1  2976789         2878  CIRCUITOS ALUMBRADO C/V TS-ALUMBRADO TOMAS 480...
# 2      NaN         2907  INTERCAMBIADOR PLACAS 2 U1 TS-MARCA ALFA-LAVA-...
# 3  2977052         3069             TABLERO TURBINA U2 TS-MARCA NEYRPIC---
# 4  2977266         2955  MOTOBOMBA 2 AGUA FRIA TS-MARCA SIHI-HALB-SISTE...
#
#   WORKTYPE SLXNUMTOT                      SLXDESCOT SLXFECCREACIONOT  \
# 0       MP   1000740               REVISION GENERAL        14/2/2007
# 1       MP   1001233                REVISION GENRAL        15/2/2007
# 2       MP   1001382       LAVAR INT PLACAS 2 U1 TS        16/2/2007
# 3    CPROG   1001383   MALA SEÑALIZ TABL TURB U1 TS        16/2/2007
# 4    CPROG   1001386  FUGA AGUA PRENSOEST AFFA-2 TS        16/2/2007
#
#   SLXFECINICIOOT SLXFECFINOT                         DOCUMENT
# 0      14/2/2007   14/2/2007  HISTORIAJDE_01312033_OT_1000740
# 1      15/2/2007   15/2/2007  HISTORIAJDE_01312033_OT_1001233
# 2      16/2/2007   16/2/2007  HISTORIAJDE_01312033_OT_1001382
# 3      16/2/2007   16/2/2007  HISTORIAJDE_01312033_OT_1001383
# 4      16/2/2007   16/2/2007  HISTORIAJDE_01312033_OT_1001386

# %%
wonew = pd.read_excel(repo_dir+"RegistrosOrdenesDeTrabajo.xlsx")
wonew.head()
# Out:
#    WONUM                             DESCRIPTION  ASSETNUM WORKTYPE  \
# 0  81187          R/V SOFTWARE SCADA LA TASAJERA   2977213    CPROG
# 1  81011                   LAVAR JUEGO DE PLACAS   2976926    CPROG
# 2  82516  R/P REPARAR VALVULA MANUAL DEL BY-PASS   2976936    CINME
# 3  82567              REPARAR AGUJAS DE REPUESTO   2976937    CINME
# 4  83539        CORREGIR FUGA DE ACEITE CGI - U1   2976933    CINME
#
#                REPORTDATE                ACTSTART               ACTFINISH  \
# 0 2018-07-17 09:13:14.999 2018-08-01 10:58:12.000 2018-12-20 08:25:17.999
# 1 2018-07-17 07:35:10.999 2018-07-16 06:59:59.999 2018-07-17 10:20:17.999
# 2 2018-07-18 15:06:53.999 2018-11-26 06:59:59.999 2018-11-26 12:59:59.999
# 3 2018-07-18 15:50:47.999 2018-07-18 15:50:47.999 2020-12-04 10:44:12.000
# 4 2018-07-19 14:43:19.999 2018-07-19 14:43:21.000 2018-08-08 10:42:17.000
#
#                                           PROBLEM  \
# 0                              CONTROL DEFICIENTE
# 1                                     OBSTRUCCION
# 2                            RETORNO NO ACCIONADO
# 3  DANO EN RECUBRIMIENTO, ABOLLADURA, DEFORMACION
# 4                                            FUGA
#
#                                                CAUSE    REMEDY  \
# 0                    CABLE DE PUESTA A TIERRA SUELTO  CONECTAR
# 1    ELEMENTOS EXTRANOS O CONTAMINANTES EN EL FLUIDO   LIMPIAR
# 2                                               FUGA   REPARAR
# 3  DESPLAZAMIENTO DEL TERRENO, DESLIZAMIENTO, ERO...   REPARAR
# 4  FALLA EN ACCESORIO (VALVULA, SELLO, EMPAQUE, B...   CAMBIAR
#
#                                              WORKLOG
# 0  <html><div>AJUSTE DE LA HORA EN SCADA.</div><d...
# 1  <html><font size="2"> </font>\n<b>\n  <font fa...
# 2  <html><font size="2"><p>SOLICITANTE:</p>\n<p>R...
# 3  <html><font color="#000000" face="Times New Ro...
# 4  <html><font size="2"><p>SOLICITANTE:</p>\n<p>C...
